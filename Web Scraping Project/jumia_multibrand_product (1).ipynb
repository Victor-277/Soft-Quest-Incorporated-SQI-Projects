# %%
import pandas as pd
import time
import os
from selenium import webdriver  
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys  
from bs4 import BeautifulSoup as soup

# Initialize the browser once
service = Service(ChromeDriverManager().install())
browser = webdriver.Chrome(service=service)
browser.get("https://www.jumia.com.ng/")
time.sleep(2)

products = [
    "infinix phones",
    "samsung phones",
    "tecno phones",
    "redmi phones",
    "iphone phones"
] 

product_urls = []

for product in products:
    try:
        print(f"\n🔍 Searching: {product}")
        browser.get("https://www.jumia.com.ng/")
        time.sleep(3)

        search_box = browser.find_element(By.XPATH, '//*[@id="fi-q"]')
        search_box.click()
        search_box.send_keys(Keys.CONTROL, 'a')
        search_box.send_keys(Keys.BACKSPACE)
        time.sleep(1)
        search_box.send_keys(product)
        search_box.send_keys(Keys.ENTER)
        time.sleep(5)

        total_collected = 0
        page_number = 1
        max_per_product = 20

        while total_collected < max_per_product:
            html_source = browser.page_source
            page_soup = soup(html_source, 'html.parser')
            containers = page_soup.find_all("a", {"class": "core"})

            if not containers:
                print(f"⚠️ No more products on page {page_number}")
                break

            new_links = 0
            for container in containers:
                url = container.get("href")
                if url:
                    full_url = f"https://www.jumia.com.ng{url}"
                    if full_url not in product_urls:
                        product_urls.append(full_url)
                        total_collected += 1
                        new_links += 1
                        if total_collected >= max_per_product:
                            break

            print(f"✅ Page {page_number}: {new_links} new links added")

            try:
                next_btn = browser.find_element(By.CSS_SELECTOR, 'a.pg[aria-label="Next"]')
                browser.execute_script("arguments[0].scrollIntoView();", next_btn)
                next_btn.click()
                page_number += 1
                time.sleep(5)
            except:
                print("🚫 No more pages available.")
                break

    except Exception as e:
        print(f"❌ Error scraping {product}: {e}")
        continue

# Save URLs
pd.DataFrame(product_urls, columns=["product_URL"]).to_csv("jumia_multibrand_urls.csv", index=False)
print(f"\n✅ Total unique product URLs collected: {len(product_urls)}")
browser.quit()

# -------------------------------
# SCRAPE EACH PRODUCT PAGE
# -------------------------------
browser = webdriver.Chrome(service=service)

# Load previous data if it exists
previous_data = {}
if os.path.exists("scraped_jumia_multibrand_products.csv"):
    previous_df = pd.read_csv("scraped_jumia_multibrand_products.csv")
    previous_data = {row['URL']: row for _, row in previous_df.iterrows()}

# Lists to store data
product_name = []
price = []
product_brand = []
product_rating = []
product_reviews = []
product_image = []
product_unit = []
discount = []
original_price = []
final_urls = []

for index, url in enumerate(product_urls):
    print(f"Scraping {index + 1}/{len(product_urls)}: {url}")
    browser.get(url)
    time.sleep(5)
    html_source = browser.page_source
    page_soup = soup(html_source, 'html.parser')

    # Brand
    try:
        all_links = page_soup.find_all("a", {"class": "_more"})
        brand = None
        for link in all_links:
            href = link.get("href", "")
            if href.startswith("/") and "/sp-" not in href and "privacy" not in href:
                brand = link.text.strip()
                break
        if not brand:
            brand = "No brand found"
    except:
        brand = "No brand found"

    # Name
    try:
        name = page_soup.find("h1", {"class": "-fs20 -pts -pbxs"}).text.strip()
    except:
        name = "No name found"

    # Current Price
    try:
        new_price = page_soup.find("span", {"class": "-b -ubpt -tal -fs24 -prxs"}).text.strip()
    except:
        new_price = "No price found"

    # Original Price
    try:
        orig_price = page_soup.find("span", {"class": "-tal -gy5 -lthr -fs16 -pvxs -ubpt"}).text.strip()
    except:
        orig_price = "No original price"

    # Discount
    try:
        disc = page_soup.find("span", {"class": "bdg _dsct _dyn -mls"}).text.strip()
    except:
        disc = "No discount"

    # Image
    try:
        image = page_soup.find("img", {"class": "-fw -fh"})["src"]
    except:
        image = "No image"

    # Rating
    try:
        rating = page_soup.find("div", {"class": "stars _m _al"}).text.strip()
    except:
        rating = "No rating"

    # Reviews
    try:
        reviews = page_soup.find("a", {"class": "-plxs _more"}).text.strip()
    except:
        reviews = "No reviews"

    # Unit Left
    try:
        units = page_soup.find("p", {"class": "-df -i-ctr -fs12 -pbs -yl7"}).text.strip()
    except:
        units = "No unit left"

    # Store
    product_brand.append(brand)
    product_name.append(name)
    price.append(new_price)
    product_rating.append(rating)
    product_reviews.append(reviews)
    product_unit.append(units)
    discount.append(disc)
    original_price.append(orig_price)
    product_image.append(image)
    final_urls.append(url)

    print(f"✔️ Done: {name}")

# Final Data
data = {
    "Brand": product_brand,
    "Name": product_name,
    "Price": price,
    "Rating": product_rating,
    "NumberOfReviews": product_reviews,
    "Original Price": original_price,
    "Unit Left": product_unit,
    "Discount": discount,
    "Image": product_image,
    "URL": final_urls
}

# Save to CSV
df = pd.DataFrame(data)
df.to_csv("scraped_jumia_multibrand_products.csv", index=False)
browser.quit()

print("✅ Scraping complete. Data saved to 'scraped_jumia_multibrand_products.csv'")
# Out:
# 🔍 Searching: infinix phones
# ✅ Page 1: 20 new links added
# 🚫 No more pages available.
#
# 🔍 Searching: samsung phones
# ✅ Page 1: 20 new links added
# 🚫 No more pages available.
#
# 🔍 Searching: tecno phones
# ✅ Page 1: 20 new links added
# 🚫 No more pages available.
#
# 🔍 Searching: redmi phones
# ✅ Page 1: 20 new links added
# 🚫 No more pages available.
#
# 🔍 Searching: iphone phones
# ✅ Page 1: 20 new links added
# 🚫 No more pages available.
#
# ✅ Total unique product URLs collected: 100
# Scraping 1/100: https://www.jumia.com.ng/infinix-smart-9hd-6.7-4gb-ram64gb-rom-jumia-only-black-411755963.html
# ✔️ Done: Infinix Smart 9HD 6.7" 4GB RAM/64GB ROM Jumia Only Black
# Scraping 2/100: https://www.jumia.com.ng/infinix-smart-9hd-6.7-4gb-ram64gb-rom-titanium-384822967.html
# ✔️ Done: Infinix Smart 9HD 6.7" 4GB RAM/64GB ROM Titanium
# Scraping 3/100: https://www.jumia.com.ng/infinix-hot-50i-smart-phone-with-128gb-rom-4gb-ram-380388798.html
# ✔️ Done: Infinix Hot 50i Smart Phone With 128GB ROM & 4GB RAM
# Scraping 4/100: https://www.jumia.com.ng/infinix-hot-50i-6.78-4gb-ram128gb-rom-android-13-black-379788039.html
# ✔️ Done: Infinix Hot 50i 6.78" 4GB RAM/128GB ROM Android 13- Black
# Scraping 5/100: https://www.jumia.com.ng/infinix-smart-8-smart-phone-with-64gb-rom-2gb-ram-377439995.html
# ✔️ Done: Infinix Smart 8 Smart Phone With 64GB ROM & 2GB RAM
# Scraping 6/100: https://www.jumia.com.ng/infinix-hot-50i-smart-phone-with-128gb-rom-4gb-ram-409688547.html
# ✔️ Done: Infinix Hot 50i Smart Phone With 128GB ROM & 4GB RAM
# Scraping 7/100: https://www.jumia.com.ng/infinix-smart-10-hd-6.6-64gb2gb2gb-ram-8mp-13mp-5000mah-black-415906842.html
# ✔️ Done: Infinix Smart 10 HD, 6.6", 64gb/2gb+2gb RAM, 8MP+ 13MP, 5000mAh- Black
# Scraping 8/100: https://www.jumia.com.ng/infinix-smart-9-6.7-3gb-ram128gb-rom-android-14-go-black-390072379.html
# ✔️ Done: Infinix Smart 9  6.7" 3GB RAM/128GB ROM Android 14 Go Black
# Scraping 9/100: https://www.jumia.com.ng/infinix-smart-9-6.7-3gb-ram128gb-rom-14-go-gold-379792093.html
# ✔️ Done: Infinix Smart 9   6.7" 3GB RAM/128GB ROM 14 Go Gold
# Scraping 10/100: https://www.jumia.com.ng/infinix-note-50-6.78-8gb-ram-256gb-rom-android-14-412385572.html
# ✔️ Done: Infinix Note 50 6.78" 8GB RAM 256GB ROM Android 14
# Scraping 11/100: https://www.jumia.com.ng/infinix-smart-9-6.7-hd-3gb-ram128gb-rom-android-14-go-green-379792055.html
# ✔️ Done: Infinix Smart 9   6.7" HD 3GB RAM/128GB ROM Android 14 Go Green
# Scraping 12/100: https://www.jumia.com.ng/infinix-note-50-pro-6.78-1212gb-ram-256gb-rom-android-15-50mp-32mp-selfie-dual-sim-5000mah-5g-titanum-grey-409286900.html
# ✔️ Done: Infinix Note 50 Pro+ - 6.78" (12+12GB RAM, 256GB ROM) Android 15 - 50MP + 32MP Selfie -  Dual Sim - 5000mAh - 5G - Titanum Grey
# Scraping 13/100: https://www.jumia.com.ng/infinix-hot-40i-6.78-8gb-ram256gb-rom-android-13-green-404484007.html
# ✔️ Done: Infinix HOT 40i - 6.78" - 8GB RAM/256GB ROM - Android 13 - Green
# Scraping 14/100: https://www.jumia.com.ng/infinix-smart-9-6.7-3gb-ram128gb-rom-android-14-go-gold-390152831.html
# ✔️ Done: Infinix Smart 9   6.7" 3GB RAM/128GB ROM Android 14 Go Gold
# Scraping 15/100: https://www.jumia.com.ng/infinix-note-50-pro-6.78-1212gb-ram-256gb-rom-android-15-50mp-32mp-selfie-dual-sim-5000mah-5g-titanum-grey-409286880.html
# ✔️ Done: Infinix Note 50 Pro+ - 6.78" (12+12GB RAM, 256GB ROM) Android 15 - 50MP + 32MP Selfie -  Dual Sim - 5000mAh - 5G - Titanum Grey
# Scraping 16/100: https://www.jumia.com.ng/infinix-smart-9-hd-6.7-64g-33gb-ram-dual-sim-8mp-13mp-5000mah-black-404852818.html
# ✔️ Done: Infinix Smart 9 HD 6.7" - 64G - 3+3GB RAM, Dual Sim - 8MP+ 13MP, 5000mAh- Black
# Scraping 17/100: https://www.jumia.com.ng/hot-50i-6.7-128gb44gb-4g-dual-sim-48mp-fingerprint-5000mah-green-infinix-mpg9629522.html
# ✔️ Done: Infinix HOT 50i - 6.7" (128GB/4+4GB) 4G Dual SIM - 48MP - Fingerprint - 5000mAh - Green
# Scraping 18/100: https://www.jumia.com.ng/infinix-smart-9hd-6.7-3gb-ram64gb-rom-android-14-go-black-390073529.html
# ✔️ Done: Infinix Smart 9HD   6.7" 3GB RAM/64GB ROM Android 14 Go Black
# Scraping 19/100: https://www.jumia.com.ng/infinix-note-50pro-6.78-88gb-ram-256gb-rom-android-15-508mp-32mp-selfie-dual-sim-5200mah-enchanted-purple-411202515.html
# ✔️ Done: Infinix Note 50Pro - 6.78" (8+8GB RAM, 256GB ROM) Android 15 (50/8)MP + 32MP Selfie - Dual Sim -  5200mAh - Enchanted Purple
# Scraping 20/100: https://www.jumia.com.ng/note-40-pro-6.78-256gb88gb-4g-108mp-5000mah-green-infinix-mpg6700956.html
# ✔️ Done: Infinix Note 40 Pro - 6.78" (256GB/8+8GB) 4G, 108MP, 5000mAh - Green
# Scraping 21/100: https://www.jumia.com.ng/samsung-galaxy-a05-6.7-4gb-ram64gb-rom-android-13-black-402050267.html
# ✔️ Done: Samsung Galaxy A05 6.7" 4GB RAM/64GB ROM Android 13 - Black
# Scraping 22/100: https://www.jumia.com.ng/samsung-galaxy-a05-6.7-4gb-ram64gb-rom-android-13-black-397109308.html
# ✔️ Done: Samsung Galaxy A05 6.7" 4GB RAM/64GB ROM Android 13 - Black
# Scraping 23/100: https://www.jumia.com.ng/samsung-galaxy-a06-6.7-4gb-ram-128gb-rom-android-14-black-384423199.html
# ✔️ Done: Samsung Galaxy A06 6.7" 4GB RAM/ 128GB ROM Android 14 - Black
# Scraping 24/100: https://www.jumia.com.ng/samsung-galaxy-a06-6.7-4gb-ram64gb-rom-android-14-black-401614385.html
# ✔️ Done: Samsung Galaxy A06 6.7" 4GB RAM/64GB ROM Android 14 - Black
# Scraping 25/100: https://www.jumia.com.ng/samsung-galaxy-a16-6.7-hd-4gb-ram128gb-rom-android-14-5000mah-black-391241450.html
# ✔️ Done: Samsung Galaxy A16 6.7" HD 4GB RAM/128GB ROM Android 14 5000mah - Black
# Scraping 26/100: https://www.jumia.com.ng/samsung-galaxy-a56-6.7-8gb-ram128gb-rom-awesome-graphite-407383843.html
# ✔️ Done: Samsung Galaxy A56 6.7" 8GB RAM/128GB ROM -  Awesome Graphite
# Scraping 27/100: https://www.jumia.com.ng/samsung-galaxy-a36-6.7-8gb-ram256gb-rom-android-15-black-407383833.html
# ✔️ Done: Samsung Galaxy A36 6.7" 8GB RAM/256GB ROM Android 15 - Black
# Scraping 28/100: https://www.jumia.com.ng/samsung-galaxy-a06-6.7-6gb-ram-128gb-rom-android-14-dual-sim-black-404480316.html
# ✔️ Done: Samsung Galaxy A06 6.7" 6GB RAM 128GB ROM Android 14 Dual SIM - Black
# Scraping 29/100: https://www.jumia.com.ng/samsung-galaxy-a06-6.7-4gb-ram128gb-rom-android-14-black-401614264.html
# ✔️ Done: Samsung Galaxy A06 6.7" 4GB RAM/128GB ROM Android 14 - Black
# Scraping 30/100: https://www.jumia.com.ng/samsung-galaxy-a06-6.7-6gb-ram-128gb-rom-android-14-dual-sim-light-blue-403167029.html
# ✔️ Done: Samsung Galaxy A06 6.7" 6GB RAM 128GB ROM Android 14 Dual SIM - Light Blue
# Scraping 31/100: https://www.jumia.com.ng/samsung-galaxy-a16-6.7-hd-6gb-ram128gb-rom-android-14-black-416906296.html
# ✔️ Done: Samsung Galaxy A16 6.7" HD 6GB RAM/128GB ROM Android 14  - Black
# Scraping 32/100: https://www.jumia.com.ng/samsung-galaxy-a16-4g-4gb128gb-dual-sim-light-green-5000mah-395381034.html
# ✔️ Done: Samsung GALAXY A16 4G 4GB/128GB DUAL SIM LIGHT GREEN 5000MAH
# Scraping 33/100: https://www.jumia.com.ng/samsung-galaxy-s21-ultra-5g-6.8-256gb12gb-1sim-titanium-black-369548272.html
# ✔️ Done: Samsung Galaxy S21 Ultra 5G - 6.8" 256GB/12GB, 1Sim - Titanium Black
# Scraping 34/100: https://www.jumia.com.ng/samsung-galaxy-note20-single-sim-128gb-8gb-ram-5g-361489079.html
# ✔️ Done: Samsung Galaxy Note20 SINGLE SIM (128GB 8GB RAM) 5G
# Scraping 35/100: https://www.jumia.com.ng/samsung-galaxy-note-10-6.3-256gb8gb-single-sim-aura-glow-369453237.html
# ✔️ Done: Samsung Galaxy Note 10 - 6.3" 256GB/8GB, Single Sim - Aura Glow
# Scraping 36/100: https://www.jumia.com.ng/samsung-galaxy-a05-4gb-ram-64gb-rom-light-green-305242237.html
# ✔️ Done: Samsung Galaxy A05 4GB RAM + 64GB ROM Light Green
# Scraping 37/100: https://www.jumia.com.ng/samsung-galaxy-a05-4gb-ram-64gb-rom-dual-sim-5000mah-silver-278868164.html
# ✔️ Done: Samsung GALAXY A05 4GB RAM 64GB ROM DUAL SIM -5000mAh SILVER
# Scraping 38/100: https://www.jumia.com.ng/samsung-galaxy-s25-ultra-dual-sim-12gb-1tb-5g-titanium-whitesilver-401735821.html
# ✔️ Done: Samsung Galaxy S25 Ultra Dual SIM - 12GB - 1TB - 5G - Titanium  WhiteSilver
# Scraping 39/100: https://www.jumia.com.ng/samsung-galaxy-s22-ultra-5g-6.8-256gb12gb-single-sim-esim-black-369548352.html
# ✔️ Done: Samsung Galaxy S22 Ultra 5G - 6.8" 256GB/12GB, Single SIM + ESIM - Black
# Scraping 40/100: https://www.jumia.com.ng/samsung-galaxy-s21-6.2-single-sim-5g-12mp64mp-1288gb-4000mah-261588825.html
# ✔️ Done: Samsung GALAXY S21  6.2" SINGLE SIM 5G (12MP+64MP) 128/8GB 4000mAh
# Scraping 41/100: https://www.jumia.com.ng/tecno-pop-9-6.67-3gb-ram-128gb-rom-android-14-black-387909806.html
# ✔️ Done: Tecno Pop 9 6.67" 3GB RAM / 128GB ROM Android 14 -Black
# Scraping 42/100: https://www.jumia.com.ng/tecno-pop-9-6.67-4gb-ram-128gb-rom-android-14-black-383309226.html
# ✔️ Done: Tecno Pop 9 6.67" 4GB RAM / 128GB ROM Android 14 - Black
# Scraping 43/100: https://www.jumia.com.ng/tecno-t101-1.8-dual-sim-black-382115813.html
# ✔️ Done: Tecno T101 1.8" Dual SIM  - Black
# Scraping 44/100: https://www.jumia.com.ng/tecno-pop-9-6.67-3gb-ram-64gb-rom-android-14-gold-408798006.html
# ✔️ Done: Tecno Pop 9 6.67" 3GB RAM /64GB ROM Android 14 - Gold
# Scraping 45/100: https://www.jumia.com.ng/tecno-pop10-6gb-ram-33gb-extended-64gb-rom-6.67-120hz-display-5000mah-battery-13mp-ai-camera-4g-lte-417022450.html
# ✔️ Done: Tecno Pop10 – 6GB RAM (3+3GB Extended), 64GB ROM – 6.67” 120Hz Display, 5000mAh Battery, 13MP AI Camera, 4G LTE
# Scraping 46/100: https://www.jumia.com.ng/tecno-t315-big-screen-fm-loud-speaker-big-battery-black-42219923.html
# ✔️ Done: Tecno T315, Big Screen, FM Loud Speaker, Big Battery, Black
# Scraping 47/100: https://www.jumia.com.ng/tecno-spark-40-6.6-hd-display-128gb-rom-4gb-ram-50mp-ai-camera-4g-lte-417863750.html
# ✔️ Done: Tecno  Spark 40 – 6.6” HD+ Display, 128GB ROM + 4GB RAM, 50MP AI Camera, 4G LTE
# Scraping 48/100: https://www.jumia.com.ng/tecno-spark-30c-6.67rom-128gbram-4gb-4g5000mah-black-374392004.html
# ✔️ Done: Tecno Spark 30C-6.67"(ROM 128GB/RAM 4GB) 4G,5000mAh -Black
# Scraping 49/100: https://www.jumia.com.ng/tecno-camon-40pro-6.78-88gb-ram-256gb-rom-android-15-508mp-50mp-selfie-dual-sim-4g-lte-5200mah-409344035.html
# ✔️ Done: Tecno Camon 40Pro - 6.78" 8+8GB RAM, 256GB ROM Android 15 (50/8)MP + 50MP Selfie - Dual Sim - 4G LTE - 5200mAh
# Scraping 50/100: https://www.jumia.com.ng/tecno-spark-30c-6.6-6gb-ram128gb-rom-android-14-black-404850417.html
# ✔️ Done: Tecno Spark 30C 6.6" 6GB RAM/128GB ROM Android 14 - Black
# Scraping 51/100: https://www.jumia.com.ng/tecno-spark-30c-6.6-4gb-ram128gb-rom-android-14-black-369779069.html
# ✔️ Done: Tecno Spark 30C 6.6" 4GB RAM/128GB ROM Android 14 - Black
# Scraping 52/100: https://www.jumia.com.ng/tecno-pop-9-6.67-64gb-rom-33gb-ram-4g-lte-dual-sim-fingerprint-5000mah-405821022.html
# ✔️ Done: Tecno Pop 9 - 6.67" - 64GB ROM - 3+3GB RAM - 4G LTE - Dual SIM - Fingerprint - 5000mAh
# Scraping 53/100: https://www.jumia.com.ng/tecno-camon-30-premier-5g-cl9-12gb-512gb-android-14-black-382621676.html
# ✔️ Done: Tecno Camon 30 Premier 5G CL9 12GB/ 512GB Android 14 - Black
# Scraping 54/100: https://www.jumia.com.ng/tecno-t402-2.4inchesjava-tripple-sim-gsm-opera-mini-0.08mp0.08mp-1500mah-champaign-gold...-58110197.html
# ✔️ Done: Tecno T402, 2.4Inches,Java, Tripple Sim, GSM, Opera Mini, 0.08MP+0.08MP, 1500mAh, Champaign Gold...
# Scraping 55/100: https://www.jumia.com.ng/tecno-camon-40-6.78-8gb-ram-256gb-rom-android-15-508mp-32mp-selfie-4g-lte-5200mah-galaxy-black-409273687.html
# ✔️ Done: Tecno Camon 40 - 6.78" (8GB RAM, 256GB ROM) Android 15 (50/8)MP + 32MP Selfie - 4G LTE - 5200mAh - Galaxy Black
# Scraping 56/100: https://www.jumia.com.ng/tecno-spark-30c-6.6-4gb-ram128gb-rom-android-14-black-401716006.html
# ✔️ Done: Tecno Spark 30C 6.6" 4GB RAM/128GB ROM Android 14 - Black
# Scraping 57/100: https://www.jumia.com.ng/tecno-phantom-v-fold-2-ae10-7.85-12gb-512gb-android-14-blue-382517073.html
# ✔️ Done: Tecno Phantom V Fold 2 AE10 7.85" 12GB/ 512GB Android 14 - Blue
# Scraping 58/100: https://www.jumia.com.ng/tecno-spark-30-pro-6.78-8gb-ram128gb-rom-dual-sim-android-14-arctic-glow-404850958.html
# ✔️ Done: Tecno Spark 30 Pro 6.78" 8GB RAM/128GB ROM, Dual Sim, Android 14 - Arctic Glow
# Scraping 59/100: https://www.jumia.com.ng/tecno-pop10-c-6.6-display-64gb-rom-2gb-ram-expandable-to-4gb-5000mah-battery-android-13-fast-reliable-stylish-416467271.html
# ✔️ Done: Tecno POP10 C – 6.6" Display, 64GB ROM + 2GB RAM Expandable to 4GB, 5000mAh Battery, Android 13 – Fast, Reliable, Stylish
# Scraping 60/100: https://www.jumia.com.ng/spark-20-pro-6.78-256gb88gb-4g-lte-5000mah-black-tecno-mpg7974505.html
# ✔️ Done: Tecno Spark 20 Pro - 6.78" (256GB/8+8GB) 4G LTE, 5000mAh - Black
# Scraping 61/100: https://www.jumia.com.ng/xiaomi-redmi-a5-6.88-4gb-ram128gb-rom-android-15-ocean-blue-408260993.html
# ✔️ Done: No name found
# Scraping 62/100: https://www.jumia.com.ng/xiaomi-redmi-14c-6.88-8gbram256gb-rom-android-14-midnight-black-369584804.html
# ✔️ Done: XIAOMI Redmi 14C 6.88'' 8GBRAM/256GB ROM Android 14 -Midnight Black
# Scraping 63/100: https://www.jumia.com.ng/xiaomi-redmi-a5-6.88-3gb-ram64gb-rom-black-408237967.html
# ✔️ Done: XIAOMI REDMI A5 -  6.88   3GB RAM/64GB ROM  -- BLACK
# Scraping 64/100: https://www.jumia.com.ng/xiaomi-redmi-pad-se-4gb-ram128gb-rom-android-13-wifi-only-grey-404106500.html
# ✔️ Done: XIAOMI Redmi PAD SE 4GB RAM/128GB ROM Android 13 WiFi Only - Grey
# Scraping 65/100: https://www.jumia.com.ng/xiaomi-redmi-note-14-pro-5g-6.67-12gb-ram512-gb-rom-hyperos-midnight-black-401043824.html
# ✔️ Done: XIAOMI Redmi Note 14 Pro+ 5G 6.67" 12GB RAM/512 GB ROM HyperOS - Midnight Black
# Scraping 66/100: https://www.jumia.com.ng/xiaomi-redmi-a5-6.88-3gb-ram64gb-rom-android-15-black-408323169.html
# ✔️ Done: XIAOMI Redmi A5 6.88" 3GB RAM/64GB ROM Android 15 - Black
# Scraping 67/100: https://www.jumia.com.ng/xiaomi-redmi-a3x-6.71-3gb-ram64gb-rom-android-14-black-363486606.html
# ✔️ Done: XIAOMI Redmi A3x 6.71" 3GB RAM/64GB ROM Android 14 - Black
# Scraping 68/100: https://www.jumia.com.ng/xiaomi-redmi-14c-6.88-4gb-ram128gb-rom-android-14-midnight-black..-401965648.html
# ✔️ Done: XIAOMI Redmi 14C 6.88'' 4GB RAM/128GB ROM Android 14 -Midnight Black..
# Scraping 69/100: https://www.jumia.com.ng/xiaomi-redmi-14c-6.88-6gb-ram128gb-rom-android-14-midnight-black-371004007.html
# ✔️ Done: XIAOMI Redmi 14C 6.88'' 6GB RAM/128GB ROM Android 14 - Midnight Black
# Scraping 70/100: https://www.jumia.com.ng/xiaomi-redmi-a5-6.88-3gb-ram64gb-rom-sandy-gold-408323204.html
# ✔️ Done: XIAOMI REDMI A5 -  6.88   3GB RAM/64GB ROM  -- Sandy Gold
# Scraping 71/100: https://www.jumia.com.ng/xiaomi-redmi-a3x-6.71-3gb-ram64gb-rom-android-12-black-337684776.html
# ✔️ Done: XIAOMI Redmi A3X 6.71" 3GB RAM/64GB ROM Android 12 - Black
# Scraping 72/100: https://www.jumia.com.ng/xiaomi-redmi-14c-6.88-8gb-ram256gb-rom-android-14-midnight-black-404201992.html
# ✔️ Done: XIAOMI Redmi 14C 6.88'' 8GB RAM/256GB ROM Android 14 - Midnight Black
# Scraping 73/100: https://www.jumia.com.ng/redmi-13c-6.74-256gb-rom-8gb-ram-4g-lte-dual-sim-fingerprint-5000mah-black-xiaomi-mpg10227279.html
# ✔️ Done: XIAOMI Redmi 13c - 6.74" - 256GB ROM - 8GB RAM - 4g Lte - Dual Sim - Fingerprint - 5000mAh - BLACK
# Scraping 74/100: https://www.jumia.com.ng/xiaomi-redmi-pad-pro-12.1-8gb-ram256gb-rom-android-14-grey-369790709.html
# ✔️ Done: XIAOMI Redmi Pad Pro 12.1" 8GB RAM/256GB ROM Android 14 - Grey
# Scraping 75/100: https://www.jumia.com.ng/redmi-pad-se-8.7-wifi-4gb-ram-64gb-rom-graphite-grey-xiaomi-mpg6959338.html
# ✔️ Done: XIAOMI REDMI PAD SE 8.7 WIFI 4GB RAM 64GB ROM GRAPHITE GREY
# Scraping 76/100: https://www.jumia.com.ng/redmi-a3-pro-4gb128gb-dual-sim-5160mah-navy-blue-xiaomi-mpg7792038.html
# ✔️ Done: XIAOMI REDMI A3  PRO 4GB/128GB-DUAL SIM-5160MAH-NAVY BLUE
# Scraping 77/100: https://www.jumia.com.ng/redmi-note-14-6.67-6gb128gb-108mp-4g-dual-sim-5500mah-black-xiaomi-mpg9984760.html
# ✔️ Done: XIAOMI Redmi Note 14 - 6.67" (6GB/128GB) 108MP, 4G Dual SIM, 5500mAh - Black
# Scraping 78/100: https://www.jumia.com.ng/xiaomi-redmi-note-14-pro-5g-6.67-8gb-ram256-gb-rom-hyperos-frost-blue-401542443.html
# ✔️ Done: XIAOMI Redmi Note 14 Pro+ 5G 6.67" 8GB RAM/256 GB ROM HyperOS - Frost Blue
# Scraping 79/100: https://www.jumia.com.ng/xiaomi-redmi-14c-6.88-8gb-ram256gb-rom-android-14-blue-393545172.html
# ✔️ Done: XIAOMI Redmi 14C 6.88'' 8GB RAM/256GB ROM Android 14 - Blue
# Scraping 80/100: https://www.jumia.com.ng/xiaomi-redmi-a5-6.88-4gb-ram-128gb-rom-android-15-32mp-8mp-selfie-dual-sim-5000mah-midnight-black-408930008.html
# ✔️ Done: XIAOMI Redmi A5 - 6.88" (4GB RAM, 128GB ROM) Android 15 - 32MP +8MP Selfie - Dual Sim - 5000mAh - Midnight Black
# Scraping 81/100: https://www.jumia.com.ng/apple-iphone-12-pro-max-6.7-inch-128gb-rom-6gb-ram-ios-14-252751565.html
# ✔️ Done: Apple IPhone 12 Pro Max - 6.7-Inch - 128GB ROM, 6GB RAM - IOS 14
# Scraping 82/100: https://www.jumia.com.ng/apple-iphone-15-pro-max-6.7-512gb-nano-sim-5g-natural-titanium-382455486.html
# ✔️ Done: Apple IPhone 15 Pro Max 6.7" 512GB Nano-SIM 5G - Natural Titanium
# Scraping 83/100: https://www.jumia.com.ng/apple-iphone-16-8gb-256gb-5g-ultramarine-379768667.html
# ✔️ Done: Apple IPhone 16 - 8GB-256GB - 5G - Ultramarine
# Scraping 84/100: https://www.jumia.com.ng/apple-iphone-14-pro-max-6.7-256gb-rom-6gb-ram-nano-sim-purple-321406095.html
# ✔️ Done: Apple IPhone 14 Pro Max 6.7" (256GB ROM + 6GB RAM) Nano Sim-Purple
# Scraping 85/100: https://www.jumia.com.ng/apple-iphone-16-pro-max-8gb-512gb-5g-desert-titanium-379791562.html
# ✔️ Done: Apple IPhone 16 Pro Max  - 8GB - 512GB -5G - Desert Titanium
# Scraping 86/100: https://www.jumia.com.ng/holder-portable-phone-holder-mobile-iphone-smart-phones-foldable-389842126.html
# ✔️ Done: Holder Portable Phone Holder Mobile IPhone, Smart Phones (Foldable)
# Scraping 87/100: https://www.jumia.com.ng/renewed-apple-iphone-6-plus-99.9new-1gb-ram64gb-rom-2915mah-single-sim-5.5-inch-screen-retina-hd-camera-8mp-touch-id-refurbished-smartphone-400238925.html
# ✔️ Done: Apple IPhone 6 Plus 99.9%NEW 1GB RAM+64GB ROM 2915mAh Single SIM 5.5 Inch Screen Retina HD Camera 8MP Touch ID Refurbished Smartphone
# Scraping 88/100: https://www.jumia.com.ng/iphone-11-pro-max-6.5-inch-4gb-ram-64gb-rom-4g-gold-apple-mpg4135278.html
# ✔️ Done: Apple IPhone 11 Pro Max 6.5-Inch Super Retina (4GB RAM, 64GB ROM),iOS 4G LTE Smartphone - Gold
# Scraping 89/100: https://www.jumia.com.ng/apple-iphone-13-pro-max-6.7-256gb-rom-6gb-ram-ios-15-5g-252693061.html
# ✔️ Done: Apple IPhone 13 Pro Max 6.7" - 256GB ROM + 6GB RAM - IOS 15, 5G
# Scraping 90/100: https://www.jumia.com.ng/apple-iphone-16-pro-max-256gb-desert-titanium-392307961.html
# ✔️ Done: Apple iPhone 16 Pro Max 256GB DESERT - Titanium
# Scraping 91/100: https://www.jumia.com.ng/apple-iphone-11-6.1-inch-liquid-retina-lcd-4gb-ram-64gb-rom-ios-13-12mp12mp12mp-4g-lte-smartphone-nano-sim-purple-104448856.html
# ✔️ Done: Apple IPhone 11 6.1-Inch Liquid Retina LCD (4GB RAM, 64GB ROM) IOS 13, (12MP+12MP)+12MP 4G LTE Smartphone-Nano Sim-PURPLE
# Scraping 92/100: https://www.jumia.com.ng/apple-iphone-16-pro-max-8gb-256gb-5g-black-titanium-379784506.html
# ✔️ Done: Apple IPhone 16 Pro Max  - 8GB - 256GB -5G - Black Titanium
# Scraping 93/100: https://www.jumia.com.ng/iphone-12-pro-6.1-5g-256gb-rom-6gb-ram-pacific-blue-apple-mpg3768350.html
# ✔️ Done: Apple IPhone 12 Pro - 6.1" -5G - 256GB ROM + 6GB RAM- Pacific Blue
# Scraping 94/100: https://www.jumia.com.ng/holder-portable-phone-holder-mobile-iphone-smart-phoneslong-391664117.html
# ✔️ Done: Holder Portable Phone Holder Mobile IPhone, Smart Phones(Long)
# Scraping 95/100: https://www.jumia.com.ng/apple-iphone-12-pro-max-6.7inch-128gb-6gb-ram-ios-14-gold-218398869.html
# ✔️ Done: Apple IPhone 12 Pro Max - 6.7Inch - 128GB, 6GB RAM - IOS 14 - Gold
# Scraping 96/100: https://www.jumia.com.ng/apple-iphone-13-6.1-128gb-rom-4gb-ram-3240mah-green-271251675.html
# ✔️ Done: Apple IPhone 13 - 6.1" - 128GB ROM, 4GB RAM, 3240mAh - Green
# Scraping 97/100: https://www.jumia.com.ng/apple-iphone-16-8gb-256gb-5g-black-379768420.html
# ✔️ Done: Apple IPhone 16 - 8GB-256GB - 5G - Black
# Scraping 98/100: https://www.jumia.com.ng/apple-iphone-13-pro-5g-6.1-128gb-rom-6gb-rom-silver-271864427.html
# ✔️ Done: Apple IPhone 13 Pro 5G - 6.1" 128GB ROM, 6GB ROM - Silver
# Scraping 99/100: https://www.jumia.com.ng/iphone-12-6.1-inch-128gb-rom-5g-pacific-blue-apple-mpg1775182.html
# ✔️ Done: Apple IPhone 12, 6.1-Inch 128GB ROM 5G  - Pacific Blue  Power Bank
# Scraping 100/100: https://www.jumia.com.ng/renewed-apple-iphone-6-renewed-99.9new-32g-unlocked-fingerprint-a-264157126.html
# ✔️ Done: Apple iPhone 6 Renewed 99.9%New 32G Unlocked FingerPrint A++
# ✅ Scraping complete. Data saved to 'scraped_jumia_multibrand_products.csv'
