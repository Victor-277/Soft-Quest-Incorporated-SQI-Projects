# %%
import numpy as np
import pandas as pd

# %%
# data = pd.read_csv(r'air-quality-data-2003-2022.csv', sep=';')
# data.info()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10860\2777497029.py:1: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   daa = pd.read_csv(r'c:\numpy_work\Datasets\air-quality-data-2003-2022 (1)\air-quality-data-2003-2022.csv', sep=';')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1545180 entries, 0 to 1545179
# Data columns (total 23 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   Date Time        1545173 non-null  object
#  1   NOx              1410709 non-null  float64
#  2   NO2              1407927 non-null  float64
#  3   NO               1417044 non-null  float64
#  4   SiteID           1545180 non-null  int64
#  5   PM10             342201 non-null   float64
#  6   NVPM10           88165 non-null    float64
#  7   VPM10            88158 non-null    float64
#  8   NVPM2.5          71978 non-null    float64
# ...

# %%
# data.to_csv('air-quality-data-2003-2022.csv', sep=',', index=False)

# %%
data=pd.read_csv(r'air-quality-data-2003-2022.csv')
data.info()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12136\20703571.py:1: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv(r'air-quality-data-2003-2022.csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1545180 entries, 0 to 1545179
# Data columns (total 23 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   Date Time        1545173 non-null  object
#  1   NOx              1410709 non-null  float64
#  2   NO2              1407927 non-null  float64
#  3   NO               1417044 non-null  float64
#  4   SiteID           1545180 non-null  int64
#  5   PM10             342201 non-null   float64
#  6   NVPM10           88165 non-null    float64
#  7   VPM10            88158 non-null    float64
#  8   NVPM2.5          71978 non-null    float64
#  9   PM2.5            138142 non-null   float64
#  10  VPM2.5           71978 non-null    float64
# ...

# %%
data.describe()
# Out:
#                 NOx           NO2            NO        SiteID           PM10  \
# count  1.410709e+06  1.407927e+06  1.417044e+06  1.545180e+06  342201.000000
# mean   1.121379e+02  4.255908e+01  4.586224e+01  3.157819e+02      21.836369
# std    1.366643e+02  3.105473e+01  7.277818e+01  1.189979e+02      15.581344
# min   -3.108000e+01 -4.160000e+00 -1.771000e+01  1.880000e+02      -5.000000
# 25%    3.200000e+01  2.025000e+01  6.000000e+00  2.060000e+02      11.900000
# 50%    6.700000e+01  3.575000e+01  1.975000e+01  2.700000e+02      18.000000
# 75%    1.352500e+02  5.685883e+01  5.225000e+01  4.520000e+02      27.000000
# max    2.164250e+03  5.765000e+02  1.231250e+03  6.720000e+02     257.009000
#
#              NVPM10         VPM10       NVPM2.5          PM2.5        VPM2.5  \
# count  88165.000000  88158.000000  71978.000000  138142.000000  71978.000000
# mean      14.755603      3.259799      9.322326      11.666943      3.244797
# ...

# %%
data.head()
# Out:
#                    Date Time     NOx     NO2      NO  SiteID    PM10  NVPM10  \
# 0  2019-04-29T23:00:00+00:00  122.25   49.25   47.75     501  30.400     NaN
# 1  2019-04-30T03:00:00+00:00   42.25   35.25    4.50     501  20.275     NaN
# 2  2019-05-01T06:00:00+00:00   82.00   48.50   21.75     501  28.125     NaN
# 3  2019-05-01T18:00:00+00:00  357.25  117.75  156.50     501  27.700     NaN
# 4  2019-05-02T14:00:00+00:00  194.50   73.25   79.25     501  23.775     NaN
#
#    VPM10  NVPM2.5  PM2.5  ...  SO2  Temperature  RH  Air Pressure  \
# 0    NaN      NaN    NaN  ...  NaN          NaN NaN           NaN
# 1    NaN      NaN    NaN  ...  NaN          NaN NaN           NaN
# 2    NaN      NaN    NaN  ...  NaN          NaN NaN           NaN
# 3    NaN      NaN    NaN  ...  NaN          NaN NaN           NaN
# 4    NaN      NaN    NaN  ...  NaN          NaN NaN           NaN
#
#          Location                            geo_point_2d  \
# ...

# %%
data = data.rename(columns={'Date Time':'DateTime'})
print(data)
# Out:
#                           DateTime         NOx         NO2          NO  \
# 0        2019-04-29T23:00:00+00:00  122.250000   49.250000   47.750000
# 1        2019-04-30T03:00:00+00:00   42.250000   35.250000    4.500000
# 2        2019-05-01T06:00:00+00:00   82.000000   48.500000   21.750000
# 3        2019-05-01T18:00:00+00:00  357.250000  117.750000  156.500000
# 4        2019-05-02T14:00:00+00:00  194.500000   73.250000   79.250000
# ...                            ...         ...         ...         ...
# 1545175  2023-02-07T12:00:00+00:00  310.749908   79.097813  151.033870
# 1545176  2023-02-07T12:00:00+00:00  157.616566   63.008375   61.702946
# 1545177  2023-02-07T12:00:00+00:00  228.622528   62.537157  108.474798
# 1545178  2023-02-07T14:00:00+00:00  198.958434   75.485843   80.472720
# 1545179  2023-02-07T13:00:00+00:00  103.990594   47.646219   36.737659
#
#          SiteID    PM10  NVPM10  VPM10  NVPM2.5  PM2.5  ...  SO2  Temperature  \
# ...

# %%
data.describe()
# Out:
#                  NOx            NO2             NO        SiteID  \
# count  811897.000000  812155.000000  817598.000000  881540.00000
# mean       98.497517      39.488015      39.098264     349.09223
# std       119.136521      28.535753      62.623487     124.56917
# min        -1.019800      -1.206200      -1.500000     203.00000
# 25%        28.257200      18.750000       5.000000     215.00000
# 50%        60.250000      33.250000      17.088005     375.00000
# 75%       120.000000      53.000000      45.000000     463.00000
# max      2027.000000     576.500000    1110.500000     672.00000
#
#                 PM10        NVPM10         VPM10       NVPM2.5          PM2.5  \
# count  182729.000000  63476.000000  63476.000000  60711.000000  126875.000000
# mean       18.570911     13.975167      3.445466      9.139141      11.522119
# std        12.241658     10.617677      3.030755      9.852225      10.692900
# ...

# %%
data.head()
# Out:
#                    DateTime     NOx     NO2      NO  SiteID    PM10  NVPM10  \
# 0 2019-04-29 23:00:00+00:00  122.25   49.25   47.75     501  30.400     NaN
# 1 2019-04-30 03:00:00+00:00   42.25   35.25    4.50     501  20.275     NaN
# 2 2019-05-01 06:00:00+00:00   82.00   48.50   21.75     501  28.125     NaN
# 3 2019-05-01 18:00:00+00:00  357.25  117.75  156.50     501  27.700     NaN
# 4 2019-05-02 14:00:00+00:00  194.50   73.25   79.25     501  23.775     NaN
#
#    VPM10  NVPM2.5  PM2.5  ...  SO2  Temperature  RH  Air Pressure  \
# 0    NaN      NaN    NaN  ...  NaN          NaN NaN           NaN
# 1    NaN      NaN    NaN  ...  NaN          NaN NaN           NaN
# 2    NaN      NaN    NaN  ...  NaN          NaN NaN           NaN
# 3    NaN      NaN    NaN  ...  NaN          NaN NaN           NaN
# 4    NaN      NaN    NaN  ...  NaN          NaN NaN           NaN
#
#          Location                            geo_point_2d  \
# ...

# %% [markdown]
# Crop the file to delete any records before 00:00 1 Jan 2010 (1262304000).

# %%
data= data[data['DateTime'] >= '2010-01-01']
data
# Out:
#                           DateTime         NOx         NO2          NO  \
# 0        2019-04-29T23:00:00+00:00  122.250000   49.250000   47.750000
# 1        2019-04-30T03:00:00+00:00   42.250000   35.250000    4.500000
# 2        2019-05-01T06:00:00+00:00   82.000000   48.500000   21.750000
# 3        2019-05-01T18:00:00+00:00  357.250000  117.750000  156.500000
# 4        2019-05-02T14:00:00+00:00  194.500000   73.250000   79.250000
# ...                            ...         ...         ...         ...
# 1545175  2023-02-07T12:00:00+00:00  310.749908   79.097813  151.033870
# 1545176  2023-02-07T12:00:00+00:00  157.616566   63.008375   61.702946
# 1545177  2023-02-07T12:00:00+00:00  228.622528   62.537157  108.474798
# 1545178  2023-02-07T14:00:00+00:00  198.958434   75.485843   80.472720
# 1545179  2023-02-07T13:00:00+00:00  103.990594   47.646219   36.737659
#
#          SiteID    PM10  NVPM10  VPM10  NVPM2.5  PM2.5  ...  SO2  Temperature  \
# ...

# %%
data.to_csv('crop.csv', sep=',', index=False)
