# %%
import pandas as pd
import numpy as np

# %%
insert = pd.read_csv(r'clean.csv')
insert
# Out:
#                          DateTime         NOx         NO2          NO  SiteID  \
# 0       2019-04-29 23:00:00+00:00  122.250000   49.250000   47.750000     501
# 1       2019-04-30 03:00:00+00:00   42.250000   35.250000    4.500000     501
# 2       2019-05-01 06:00:00+00:00   82.000000   48.500000   21.750000     501
# 3       2019-05-01 18:00:00+00:00  357.250000  117.750000  156.500000     501
# 4       2019-05-02 14:00:00+00:00  194.500000   73.250000   79.250000     501
# ...                           ...         ...         ...         ...     ...
# 881535  2023-02-07 12:00:00+00:00  310.749908   79.097813  151.033870     501
# 881536  2023-02-07 12:00:00+00:00  157.616566   63.008375   61.702946     463
# 881537  2023-02-07 12:00:00+00:00  228.622528   62.537157  108.474798     672
# 881538  2023-02-07 14:00:00+00:00  198.958434   75.485843   80.472720     463
# 881539  2023-02-07 13:00:00+00:00  103.990594   47.646219   36.737659     203
#
# ...

# %%
insert_subset = insert.head(100)
insert_subset
# Out:
#                      DateTime     NOx     NO2      NO  SiteID    PM10  \
# 0   2019-04-29 23:00:00+00:00  122.25   49.25   47.75     501  30.400
# 1   2019-04-30 03:00:00+00:00   42.25   35.25    4.50     501  20.275
# 2   2019-05-01 06:00:00+00:00   82.00   48.50   21.75     501  28.125
# 3   2019-05-01 18:00:00+00:00  357.25  117.75  156.50     501  27.700
# 4   2019-05-02 14:00:00+00:00  194.50   73.25   79.25     501  23.775
# ..                        ...     ...     ...     ...     ...     ...
# 95  2019-05-30 17:00:00+00:00  152.75   54.25   64.25     501  15.700
# 96  2019-05-30 18:00:00+00:00  184.75   73.75   72.75     501  16.125
# 97  2019-05-31 05:00:00+00:00   32.00   12.00   12.75     501  11.375
# 98  2019-05-31 06:00:00+00:00   73.75   25.75   31.00     501   8.700
# 99  2019-05-31 13:00:00+00:00  288.00   80.50  135.25     501  22.500
#
#        NVPM10     VPM10   NVPM2.5      PM2.5  ...       SO2  Temperature  \
# ...

# %%
insert_subset.to_csv('cropped_clean.csv', sep=',', index=False)
